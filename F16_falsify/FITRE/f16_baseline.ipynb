# %% [markdown]
# # Choose the CPU cores number you want to use

# %%
import ray
ray.init(num_cpus=50, num_gpus=1)
# Out:
# 2020-11-15 17:11:07,727	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8268
# {'node_ip_address': '128.10.130.25',
#  'raylet_ip_address': '128.10.130.25',
#  'redis_address': '128.10.130.25:20708',
#  'object_store_address': '/tmp/ray/session_2020-11-15_17-11-06_905593_44297/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-11-15_17-11-06_905593_44297/sockets/raylet',
#  'webui_url': '127.0.0.1:8268',
#  'session_dir': '/tmp/ray/session_2020-11-15_17-11-06_905593_44297',
#  'metrics_export_port': 58782}

# %% [markdown]
# # Prepare

# %%
import CoRec
import gym
import numpy as np

import stable_baselines3 as sb3
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from ray import tune

# %% [markdown]
# # Reward is simply set as the number of safe steps

# %%
class RewardWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)

    def reward(self, r):
        if r <= -1:
            r = 0
        else:
            r += 0.1

        return r

# %% [markdown]
# # Hyper-parameters Range

# %%
def ppo_hyper(**kwargs): return kwargs

config = ppo_hyper(
    learning_rate=tune.loguniform(1e-6, 0.01),
    n_steps=tune.choice([256, 512, 1024, 2048, 4096]),
    batch_size=tune.choice([32, 64, 128, 256, 512, 1024, 2048]),
    n_epochs=tune.randint(4, 32),
    gamma=tune.uniform(0.95, 1),
    gae_lambda=tune.uniform(0.95, 0.999),
    clip_range=np.inf,
    clip_range_vf=None,
    ent_coef=0.05,
    vf_coef=tune.uniform(0.2, 0.8),
    max_grad_norm=0.5,
    use_sde=False,
    sde_sample_freq=-1,
    target_kl=None,
    seed=1
)
    
config
# Out:
# {'learning_rate': <ray.tune.sample.Float at 0x7f99ed776630>,
#  'n_steps': <ray.tune.sample.Categorical at 0x7f99ed7766a0>,
#  'batch_size': <ray.tune.sample.Categorical at 0x7f99ed776748>,
#  'n_epochs': <ray.tune.sample.Integer at 0x7f99ed776710>,
#  'gamma': <ray.tune.sample.Float at 0x7f99ed7767f0>,
#  'gae_lambda': <ray.tune.sample.Float at 0x7f99ed776860>,
#  'clip_range': inf,
#  'clip_range_vf': None,
#  'ent_coef': 0.05,
#  'vf_coef': <ray.tune.sample.Float at 0x7f99ed7768d0>,
#  'max_grad_norm': 0.5,
#  'use_sde': False,
#  'sde_sample_freq': -1,
#  'target_kl': None,
#  'seed': 1}

# %% [markdown]
# # Train
# Error can happen because numerical instability in the model itself.

# %%
def env_func(): return RewardWrapper(gym.make("F16GCAS-v3"))
env = make_vec_env(env_func, n_envs=4)

# %%
class ReportCallback(sb3.common.callbacks.BaseCallback):
    def __init__(self, verbose=0):
        super(ReportCallback, self).__init__(verbose)
        
    def _on_rollout_end(self) -> None:
        ep_rewards = [ep_info["r"] for ep_info in self.model.ep_info_buffer]
        ep_rew_mean = np.mean(ep_rewards)
        tune.report(ep_rew = ep_rew_mean)
    
    def _on_step(self) -> bool:
        return True
    
def F16_train(config):
    callback = ReportCallback()
    model = PPO(MlpPolicy, env, verbose=1, **config)
    model.learn(total_timesteps=250000, callback=callback)
    model.save("ppo_f16")
    
analysis = tune.run(F16_train, config=config, num_samples=50, verbose=1, metric="ep_rew", mode="max", raise_on_failed_trial=False)
# Out:
# == Status ==<br>Memory usage on this node: 64.7/251.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0
td><td>TERMINATED</td><td>     </td><td style="text-align: right;">        1024</td><td style="text-align: right;">    0.965693</td><td style="text-align: right;">0.987484</td><td style="text-align: right;">    0.000119445</td><td style="text-align: right;">        22</td><td style="text-align: right;">     2048</td><td style="text-align: right;"> 0.466157</td><td style="text-align: right;">    31</td><td style="text-align: right;">         417.254</td><td style="text-align: right;">154.497 </td></tr>
# <tr><td>F16_train_786c6_00009</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">        1024</td><td style="text-align: right;">    0.983197</td><td style="text-align: right;">0.972056</td><td style="text-align: right;">    1.83187e-06</td><td style="text-align: right;">         4</td><td style="text-align: right;">      512</td><td style="text-align: right;"> 0.590089</td><td style="text-align: right;">   123</td><td style="text-align: right;">         369.643</td><td style="text-align: right;"> 63.0267</td></tr>
# <tr><td>F16_train_786c6_00010</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">         512</td><td style="text-align: right;">    0.969569</td><td style="text-align: right;">0.967034</td><td style="text-align: right;">    0.00153194 </td><td style="text-align: right;">         6</td><td style="text-align: right;">     1024</td><td style="text-align: right;"> 0.427273</td><td style="text-align: right;">    62</td><td style="text-align: right;">         392.627</td><td style="text-align: right;"> 74.7095</td></tr>
# <tr><td>F16_train_786c6_00011</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">         512</td><td style="text-align: right;">    0.955782</td><td style="text-align: right;">0.983296</td><td style="text-align: right;">    0.00696878 </td><td style="text-align: right;">         5</td><td style="text-align: right;">     1024</td><td style="text-align: right;"> 0.742049</td><td style="text-align: right;">    62</td><td style="text-align: right;">         393.313</td><td style="text-align: right;">125.626 </td></tr>
# <tr><td>F16_train_786c6_00012</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">        1024</td><td style="text-align: right;">    0.989641</td><td style="text-align: right;">0.988188</td><td style="text-align: right;">    3.9324e-06 </td><td style="text-align: right;">        14</td><td style="text-align: right;">     2048</td><td style="text-align: right;"> 0.637888</td><td style="text-align: right;">    31</td><td style="text-align: right;">         395.507</td><td style="text-align: right;"> 62.8359</td></tr>
# <tr><td>F16_train_786c6_00013</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          32</td><t
# 2020-11-15 17:35:38,104	ERROR tune.py:429 -- Trials did not complete: [F16_train_786c6_00000, F16_train_786c6_00005, F16_train_786c6_00023, F16_train_786c6_00024]

# %%
ax = None
dfs = analysis.trial_dataframes
for d in dfs.values():
    ax = d.plot("training_iteration", "ep_rew", ax=ax, legend=False)

# %%
import seaborn as sns
import pandas as pd

new_frame = []
for d in dfs.values():
    new_frame.append(pd.concat([d["training_iteration"], d["ep_rew"]], axis=1))

new_frame = pd.concat(new_frame, axis=0)
new_frame.insert(2, "algo", "baseline")
new_frame.to_csv("rl_train_res/baseline.csv")
new_frame.head()
# Out:
#    training_iteration     ep_rew      algo
# 0                   1  63.945709  baseline
# 1                   2  72.893404  baseline
# 2                   3  79.614029  baseline
# 3                   4  82.378721  baseline
# 4                   5  85.292797  baseline

# %%
sns.lineplot(data=new_frame, x="training_iteration", y="ep_rew")

# %%
analysis.get_best_config(metric="ep_rew", mode="max")
# Out:
# {'learning_rate': 0.0020352118839776345,
#  'n_steps': 4096,
#  'batch_size': 2048,
#  'n_epochs': 26,
#  'gamma': 0.9789652211460462,
#  'gae_lambda': 0.9578693259177085,
#  'clip_range': inf,
#  'clip_range_vf': None,
#  'ent_coef': 0.05,
#  'vf_coef': 0.2475484116842101,
#  'max_grad_norm': 0.5,
#  'use_sde': False,
#  'sde_sample_freq': -1,
#  'target_kl': None,
#  'seed': 1}

# %%
analysis.best_dataframe.plot("training_iteration", "ep_rew")
